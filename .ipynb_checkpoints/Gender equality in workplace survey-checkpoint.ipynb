# %%
# Libraries
import pandas as pd
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats.stats import pearsonr
from scipy import stats
from scipy.stats import f_oneway



pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### 1. Load Data

# %%
data = pd.read_csv('dataset.csv')

# %%
data
# Out:
#                   Χρονική σήμανση 1. Φύλο: 2. Ηλικιακή ομάδα:  \
# 0   2023/04/28 7:07:25 μ.μ. GMT+3  Γυναίκα            18 - 25
# 1   2023/04/28 7:10:08 μ.μ. GMT+3  Γυναίκα            18 - 25
# 2   2023/04/28 7:22:54 μ.μ. GMT+3  Γυναίκα            18 - 25
# 3   2023/04/28 7:29:54 μ.μ. GMT+3  Γυναίκα            25 - 35
# 4   2023/04/28 7:42:42 μ.μ. GMT+3   Άνδρας            18 - 25
# ..                            ...      ...                ...
# 95  2023/05/23 1:56:35 μ.μ. GMT+3  Γυναίκα            25 - 35
# 96  2023/05/23 1:57:57 μ.μ. GMT+3   Άνδρας            35 - 45
# 97  2023/05/23 2:01:12 μ.μ. GMT+3  Γυναίκα            35 - 45
# 98  2023/05/23 2:04:40 μ.μ. GMT+3   Άνδρας            25 - 35
# 99  2023/05/23 2:08:00 μ.μ. GMT+3  Γυναίκα            25 - 35
#
#                               3. Επίπεδο εκπαίδευσης:  \
# 0                Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# 1                Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# 2                Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# 3                  Μεταπτυχιακή εκπαίδευση (MSc, PhD)
# 4                Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# ..                                                ...
# 95  Μεταδευτεροβάθμια εκπαίδευση μη Πανεπιστημιακή...
# 96               Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# 97  Μεταδευτεροβάθμια εκπαίδευση μη Πανεπιστημιακή...
# 98               Πανεπιστημιακή εκπαίδευση (ΑΕΙ, ΤΕΙ)
# 99                 Μεταπτυχιακή εκπαίδευση (MSc, PhD)
#
#    1. Ποιος είναι ο τίτλος ή η θέση εργασίας σας;  \
# 0                           Διοικητικός υπάλληλος
# 1                           Διοικητικός υπάλληλος
# 2                           Διοικητικός υπάλληλος
# 3                           Διοικητικός υπάλληλος
# 4                                            Άλλο
# ..                                            ...
# 95                          Διοικητικός υπάλληλος
# 96                          Διοικητικός υπάλληλος
# 97                          Διοικητικός υπάλληλος
# 98                          Διοικητικός υπάλληλος
# 99                          Προϊστάμενος Τμήματος
#
#    2. Ποιο είναι το μέγεθος της εταιρείας ή του οργανισμού στον οποίο εργάζεστε;   \
# 0                                   Μεγάλη επιχείρηση
# 1                                    Μικρή επιχείρηση
# 2                                   Μεγάλη επιχείρηση
# 3                                   Μεγάλη επιχείρηση
# 4                                    Μικρή επιχείρηση
# ..                                                ...
# 95                                  Μεσαία επιχείρηση
# 96                                  Μεγάλη επιχείρηση
# 97                                  Μεσαία επιχείρηση
# 98                                  Μεγάλη επιχείρηση
# 99                                  Μεγάλη επιχείρηση
#
#    3. Πόσα έτη εργασιακής εμπειρίας έχετε στον τρέχοντα κλάδο απασχόλησης σας;  \
# 0                                           0 - 5 έτη
# 1                                           0 - 5 έτη
# 2                                           0 - 5 έτη
# 3                                           0 - 5 έτη
# 4                                           0 - 5 έτη
# ..                                                ...
# 95                                          0 - 5 έτη
# 96                                          0 - 5 έτη
# 97                                     10 έτη και άνω
# 98                                          0 - 5 έτη
# 99                                         5 - 10 έτη
#
#    4. Ποιο είναι το τρέχον καθαρό μηνιαίο εισόδημά σας;  \
# 0                                                1300
# 1                                                 600
# 2                                                 680
# 3                                                3000
# 4                                                 910
# ..                                                ...
# 95                                           800-1000
# 96                                           800-1000
# 97                                          1000-1500
# 98                                          1000-1500
# 99                                          1000-1500
#
#    1. Ποια είναι η οικογενειακή σας κατάσταση; 2. Έχετε παιδιά;  ...  \
# 0                                       Άγαμος              Όχι  ...
# 1                                       Άγαμος              Όχι  ...
# 2                                       Άγαμος              Όχι  ...
# 3                                       Άγαμος              Όχι  ...
# 4                                       Άγαμος              Όχι  ...
# ..                                         ...              ...  ...
# 95                                      Άγαμος              Όχι  ...
# 96                                      Άγαμος              Όχι  ...
# 97                                     Έγγαμος              Ναι  ...
# 98                                      Άγαμος              Όχι  ...
# 99                                      Άγαμος              Όχι  ...
#
#    3. Πιστεύετε ότι τα στερεότυπα των φύλων έχουν επηρεάσει τις ευκαιρίες επαγγελματικής σας εξέλιξης ή τις αναθέσεις εργασίας σας;  \
# 0                                                   1
# 1                                                   1
# 2                                                   4
# 3                                                   2
# 4                                                   3
# ..                                                ...
# 95                                                  3
# 96                                                  4
# 97                                                  3
# 98                                                  2
# 99                                                  2
#
#    4. Έχετε υποστεί ποτέ παρενόχληση ή διάκριση με βάση τα στερεότυπα του φύλου στο χώρο εργασίας;   \
# 0                                                 Όχι
# 1                                                 Όχι
# 2                                                 Όχι
# 3                                                 Όχι
# 4                                                 Ναι
# ..                                                ...
# 95                                                Όχι
# 96                                                Όχι
# 97                                                Ναι
# 98                                                Όχι
# 99                                                Όχι
#
#     1. Έχετε αισθανθεί ποτέ αδικία ή διάκριση  κατά τη διαδικασία πρόσληψης βάση παραγόντων όπως το φύλο;  \
# 0                                                 Όχι
# 1                                                 Όχι
# 2                                                 Όχι
# 3                                                 Ναι
# 4                                                 Όχι
# ..                                                ...
# 95                                                Όχι
# 96                                                Όχι
# 97                                                Ναι
# 98                                                Όχι
# 99                                                Όχι
#
#     2. Έχει υποπέσει ποτέ στην αντίληψη σας ότι κάποιος υφίσταται αδικία ή διάκριση κατά τη διάρκεια της διαδικασίας πρόσληψης λόγω φύλου;  \
# 0                                                 4.0
# 1                                                 4.0
# 2                                                 4.0
# 3                                                 5.0
# 4                                                 4.0
# ..                                                ...
# 95                                                4.0
# 96                                                5.0
# 97                                                4.0
# 98                                                3.0
# 99                                                2.0
#
#     3. Πιστεύετε ότι υπάρχουν προκαταλήψεις στη διαδικασία πρόσληψης που πλήττουν ορισμένες ομάδες ανθρώπων;  \
# 0                                                 4.0
# 1                                                 3.0
# 2                                                 4.0
# 3                                                 5.0
# 4                                                 4.0
# ..                                                ...
# 95                                                5.0
# 96                                                5.0
# 97                                                5.0
# 98                                                5.0
# 99                                                5.0
#
#    4. Σας έχουν κάνει ποτέ ακατάλληλες ή αδιάκριτες ερωτήσεις κατά τη διάρκεια μιας συνέντευξης για δουλειά;   \
# 0                                                 Όχι
# 1                                                 Όχι
# 2                                                 Όχι
# 3                                                 Όχι
# 4                                                 Όχι
# ..                                                ...
# 95                                                Ναι
# 96                                                Όχι
# 97                                                Ναι
# 98                                                Όχι
# 99                                                Όχι
#
#     1. Πιστεύετε ότι σήμερα υπάρχει ισότητα μεταξύ των φύλων στον εργασιακό σας χώρο;   \
# 0                                                 Ναι
# 1                                                 Ναι
# 2                                                 Όχι
# 3                                                 Ναι
# 4                                                 Όχι
# ..                                                ...
# 95                                                Όχι
# 96                                                Όχι
# 97                                                Όχι
# 98                                                Ναι
# 99                                                Ναι
#
#     2. Αν όχι, σε ποιον κλάδο το εντοπίζετε και γιατί;  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Κλάδοι που στερεοτυπικά αφορούν άντρες παραμέν...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95               σε ολους, δεν υπάρχει πληρης ισοτητα
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#    3. Αν όχι, ποιες ενέργειες θα καθιστούσαν δυνατή τη βελτίωση;  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Σίγουρα αλλάγη των απαρχαιωμένων αντιλήψεων κα...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#    4. Κατά την άποψη σας αναφορικά με την ισότητα των φύλων που θα κατατάσσατε την Ελλάδα συγκριτικά με τα υπόλοιπα κράτη - μέλη της Ευρωπαϊκής Ένωσης;
# 0                                                 4.0
# 1                                                 3.0
# 2                                                 3.0
# 3                                                 3.0
# 4                                                 3.0
# ..                                                ...
# 95                                                3.0
# 96                                                4.0
# 97                                                2.0
# 98                                                4.0
# 99                                                3.0
#
# [100 rows x 31 columns]

# %% [markdown]
# ### 2.Clean Data

# %%
#helper functions

def converter_noyes_to_numbers(table, q):
    for index in range(len(table)):
        if table[q].iloc[index] == '΄Οχι':
            table[q].iloc[index] = 5
        elif table[q].iloc[index] == 'Ναι':
            table[q].iloc[index] = 1
        elif table[q].iloc[index] == 'Όχι':
            table[q].iloc[index] = 5

    return table

def my_reverse(table, q):
    for index in range(len(table)):
        if table[q].iloc[index] == 1:
            table[q].iloc[index] = 5
        elif table[q].iloc[index] == 2:
            table[q].iloc[index] = 4
        elif table[q].iloc[index] == 4:
            table[q].iloc[index] = 2
        elif table[q].iloc[index] == 5:
            table[q].iloc[index] = 1
    return table

# %%
q1 = '1. Έχετε αντιμετωπίσει ποτέ διακρίσεις στις αμοιβές με βάση το φύλο στην τρέχουσα ή σε προηγούμενη εργασία σας;'
q2 = '2. Σας έχει γίνει ποτέ αντιληπτό ότι το φύλο σας αποτελεί την κύρια αιτία για τις μισθολογικές διαφορές μεταξύ εσάς και των συναδέλφων σας για την πραγματοποίηση ίδιας εργασίας;'
q3 = '3. Πιστεύετε ότι υπάρχει διαφορά αμοιβών μεταξύ των φύλων στον κλάδο ή στον εργασιακό σας χώρο;'
q4 = '4. Πιστεύετε ότι ο οργανισμός που εργάζεστε εφαρμόζει τις απαραίτητες ενέργειες για την αντιμετώπιση των μισθολογικών διαφορών μεταξύ των φύλων;'

q5 = '1. Έχετε αισθανθεί ποτέ ότι υπάρχει ένα εμπόδιο που σας εμποδίζει να προχωρήσετε στις υψηλόβαθμες θέσεις στον εργασιακό σας χώρο με βάση παράγοντες όπως το φύλο; (π.χ. μητρότητα/πατρότητα, μυϊκή δύναμη κτλ.)'
q6 = '2. Πιστεύετε ότι ο χώρος εργασίας σας έχει μια ηγετική ομάδα που αντιπροσωπεύει διαφορετικά φύλα και υπόβαθρα;'
q7 = '3. Πιστεύετε ότι ο χώρος εργασίας σας έχει δίκαιες και διαφανείς διαδικασίες πρόσληψης και προαγωγής που είναι απαλλαγμένες από διακρίσεις που αφορούν στο φύλο;'
q8 = '4. Πιστεύετε ότι υπάρχει το φαινόμενο της γυάλινης οροφής (Glass Ceiling) στον κλάδο ή τον χώρο εργασίας σας;  '

q9 = '1. Έχετε βιώσει ποτέ στερεοτυπικά σχόλια αναφορικά με το φύλο σας στον χώρο εργασίας;'
q10 = '2. Έχετε αισθανθεί ποτέ ότι στερεότυπα για το φύλο επηρεάζουν κάποιον άλλο στο χώρο εργασίας;'
q11 = '3. Πιστεύετε ότι τα στερεότυπα των φύλων έχουν επηρεάσει τις ευκαιρίες επαγγελματικής σας εξέλιξης ή τις αναθέσεις εργασίας σας;'
q12 = '4. Έχετε υποστεί ποτέ παρενόχληση ή διάκριση με βάση τα στερεότυπα του φύλου στο χώρο εργασίας; '

q13 = '1. Έχετε αισθανθεί ποτέ αδικία ή διάκριση  κατά τη διαδικασία πρόσληψης βάση παραγόντων όπως το φύλο;'
q14 = '2. Έχει υποπέσει ποτέ στην αντίληψη σας ότι κάποιος υφίσταται αδικία ή διάκριση κατά τη διάρκεια της διαδικασίας πρόσληψης λόγω φύλου;'
q15 = '3. Πιστεύετε ότι υπάρχουν προκαταλήψεις στη διαδικασία πρόσληψης που πλήττουν ορισμένες ομάδες ανθρώπων;'
q16 = '4. Σας έχουν κάνει ποτέ ακατάλληλες ή αδιάκριτες ερωτήσεις κατά τη διάρκεια μιας συνέντευξης για δουλειά; '

q17 = '1. Πιστεύετε ότι σήμερα υπάρχει ισότητα μεταξύ των φύλων στον εργασιακό σας χώρο; '
q18 = '4. Κατά την άποψη σας αναφορικά με την ισότητα των φύλων που θα κατατάσσατε την Ελλάδα συγκριτικά με τα υπόλοιπα κράτη - μέλη της Ευρωπαϊκής Ένωσης;'



paying_gap = data[:][[q1,q2,q3, q4]]
glass_ceiling = data[:][[q5,q6,q7, q8]]
gender_descrimination = data[:][[q9,q10,q11, q12]]
descrimination_recruitment = data[:][[q13,q14,q15, q16]]
overall_picture = data[:][[q17,q18]]

# %% [markdown]
# #### Reverse , No or Yes questiones to numbers

# %%
paying_gap = converter_noyes_to_numbers(paying_gap, q1)
glass_ceiling = converter_noyes_to_numbers(glass_ceiling, q5)
glass_ceiling = converter_noyes_to_numbers(glass_ceiling, q8)
gender_descrimination = converter_noyes_to_numbers(gender_descrimination, q9)
gender_descrimination = converter_noyes_to_numbers(gender_descrimination, q12)
descrimination_recruitment = converter_noyes_to_numbers(descrimination_recruitment, q13)
descrimination_recruitment = converter_noyes_to_numbers(descrimination_recruitment, q16)
# Out:
# /Users/stathis/opt/anaconda3/lib/python3.9/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# /Users/stathis/opt/anaconda3/lib/python3.9/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
## Reverse questiones
paying_gap = my_reverse(paying_gap,q2)
paying_gap = my_reverse(paying_gap,q3)

# %%
gender_descrimination =  my_reverse(gender_descrimination,q10)
gender_descrimination =  my_reverse(gender_descrimination,q11)

# %%
descrimination_recruitment = my_reverse(descrimination_recruitment, q14)
descrimination_recruitment = my_reverse(descrimination_recruitment, q15)

# %%
for column in paying_gap.columns:
    paying_gap[column] = pd.to_numeric(paying_gap[column], errors='coerce')

# %%
for column in glass_ceiling.columns:
    glass_ceiling[column] = pd.to_numeric(glass_ceiling[column], errors='coerce')

# %%
for column in gender_descrimination.columns:
    gender_descrimination[column] = pd.to_numeric(gender_descrimination[column], errors='coerce')

# %%
for column in descrimination_recruitment.columns:
    descrimination_recruitment[column] = pd.to_numeric(descrimination_recruitment[column], errors='coerce')

# %% [markdown]
# ### 3. Cronabahs Alpha

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=paying_gap)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6483361199873272

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=glass_ceiling)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.43604331297664284

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=gender_descrimination)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.5943629085899009

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=descrimination_recruitment)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.5610874250352001

# %% [markdown]
# ### 4.Parameter Analysis

# %%
## Payng Gap 

relative_frequencies = paying_gap.apply(lambda x: x.value_counts(normalize=True))
relative_frequencies[q1].iloc[0] = relative_frequencies[q1].iloc[0]/3
relative_frequencies[q1].iloc[4] = relative_frequencies[q1].iloc[4]/3

# %%
relative_frequencies
# Out:
#      1. Έχετε αντιμετωπίσει ποτέ διακρίσεις στις αμοιβές με βάση το φύλο στην τρέχουσα ή σε προηγούμενη εργασία σας;  \
# 1.0                                           0.043333
# 2.0                                                NaN
# 3.0                                                NaN
# 4.0                                                NaN
# 5.0                                           0.290000
#
#      2. Σας έχει γίνει ποτέ αντιληπτό ότι το φύλο σας αποτελεί την κύρια αιτία για τις μισθολογικές διαφορές μεταξύ εσάς και των συναδέλφων σας για την πραγματοποίηση ίδιας εργασίας;  \
# 1.0                                               0.04
# 2.0                                               0.14
# 3.0                                               0.14
# 4.0                                               0.33
# 5.0                                               0.35
#
#      3. Πιστεύετε ότι υπάρχει διαφορά αμοιβών μεταξύ των φύλων στον κλάδο ή στον εργασιακό σας χώρο;  \
# 1.0                                               0.10
# 2.0                                               0.20
# 3.0                                               0.17
# 4.0                                               0.25
# 5.0                                               0.28
#
#      4. Πιστεύετε ότι ο οργανισμός που εργάζεστε εφαρμόζει τις απαραίτητες ενέργειες για την αντιμετώπιση των μισθολογικών διαφορών μεταξύ των φύλων;
# 1.0                                                NaN
# 2.0                                           0.113402
# 3.0                                           0.226804
# 4.0                                           0.371134
# 5.0                                           0.288660

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/4
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])


plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_83662/3551027262.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
height
# Out:
# 1.0    0.045833
# 2.0    0.113351
# 3.0    0.134201
# 4.0    0.237784
# 5.0    0.302165
# dtype: float64

# %%
paying_gap.describe()
# Out:
#        1. Έχετε αντιμετωπίσει ποτέ διακρίσεις στις αμοιβές με βάση το φύλο στην τρέχουσα ή σε προηγούμενη εργασία σας;  \
# count                                         100.000000
# mean                                            4.480000
# std                                             1.351991
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        2. Σας έχει γίνει ποτέ αντιληπτό ότι το φύλο σας αποτελεί την κύρια αιτία για τις μισθολογικές διαφορές μεταξύ εσάς και των συναδέλφων σας για την πραγματοποίηση ίδιας εργασίας;  \
# count                                          100.00000
# mean                                             3.81000
# std                                              1.17804
# min                                              1.00000
# 25%                                              3.00000
# 50%                                              4.00000
# 75%                                              5.00000
# max                                              5.00000
#
#        3. Πιστεύετε ότι υπάρχει διαφορά αμοιβών μεταξύ των φύλων στον κλάδο ή στον εργασιακό σας χώρο;  \
# count                                         100.000000
# mean                                            3.410000
# std                                             1.349111
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        4. Πιστεύετε ότι ο οργανισμός που εργάζεστε εφαρμόζει τις απαραίτητες ενέργειες για την αντιμετώπιση των μισθολογικών διαφορών μεταξύ των φύλων;
# count                                          97.000000
# mean                                            3.835052
# std                                             0.975538
# min                                             2.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000

# %%
## Gender

# %%
parameter = paying_gap

individualScore = parameter.sum(axis=1)/4

# %%
gender = pd.concat([data['1. Φύλο:'],individualScore],axis=1)
gender.columns = ['Gender','Score']

# %%
from statistics import mean, pvariance

male = []
female = []

#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 'Γυναίκα':
        female.append(row['Score'])
    else:
        male.append(row['Score'])
        

avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 4.09375 var male = 0.5708984375 avg female = 3.6958333333333333 var female = 0.7939409722222223

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.019672113732541442 T-Statistic:-2.37398100510319

# %%
##Provider

# %%
provider = pd.concat([data['3. Είστε ο κύριος φροντιστής για ένα νοικοκυριό; (πχ. παιδιά ή εξαρτώμενα μέλη)'],individualScore],axis=1)
provider.columns = ['Provider','Score']

# %%
from statistics import mean, pvariance

no = []
yes = []

#create table for every category
for index, row in provider.iterrows(): 
    if row['Provider'] == 'Ναι':
        yes.append(row['Score'])
    else:
        no.append(row['Score'])
        
avg1 = mean(yes)
var1 = pvariance(yes)
avg2 = mean(no)
var2 = pvariance(no)

print("avg provider =", avg1,"var provider =",var1,"avg no =", avg2,"var no =",var2 )
# Out:
# avg provider = 3.8055555555555554 var provider = 0.9205246913580247 avg no = 3.8828125 var no = 0.64056396484375

# %%
tStat, pValue = stats.ttest_ind(yes, no, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.6871928287319998 T-Statistic:-0.4045565597037937

# %% [markdown]
# ### Parameter 2 Glass_ceiling

# %%
glass_ceiling
# Out:
#     1. Έχετε αισθανθεί ποτέ ότι υπάρχει ένα εμπόδιο που σας εμποδίζει να προχωρήσετε στις υψηλόβαθμες θέσεις στον εργασιακό σας χώρο με βάση παράγοντες όπως το φύλο; (π.χ. μητρότητα/πατρότητα, μυϊκή δύναμη κτλ.)  \
# 0                                                   5
# 1                                                   5
# 2                                                   5
# 3                                                   1
# 4                                                   5
# ..                                                ...
# 95                                                  1
# 96                                                  5
# 97                                                  1
# 98                                                  1
# 99                                                  1
#
#     2. Πιστεύετε ότι ο χώρος εργασίας σας έχει μια ηγετική ομάδα που αντιπροσωπεύει διαφορετικά φύλα και υπόβαθρα;  \
# 0                                                   2
# 1                                                   1
# 2                                                   4
# 3                                                   4
# 4                                                   5
# ..                                                ...
# 95                                                  3
# 96                                                  3
# 97                                                  3
# 98                                                  4
# 99                                                  4
#
#     3. Πιστεύετε ότι ο χώρος εργασίας σας έχει δίκαιες και διαφανείς διαδικασίες πρόσληψης και προαγωγής που είναι απαλλαγμένες από διακρίσεις που αφορούν στο φύλο;  \
# 0                                                 4.0
# 1                                                 5.0
# 2                                                 1.0
# 3                                                 3.0
# 4                                                 5.0
# ..                                                ...
# 95                                                3.0
# 96                                                4.0
# 97                                                3.0
# 98                                                4.0
# 99                                                4.0
#
#     4. Πιστεύετε ότι υπάρχει το φαινόμενο της γυάλινης οροφής (Glass Ceiling) στον κλάδο ή τον χώρο εργασίας σας;
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 1.0
# 3                                                 1.0
# 4                                                 5.0
# ..                                                ...
# 95                                                1.0
# 96                                                5.0
# 97                                                1.0
# 98                                                5.0
# 99                                                5.0
#
# [100 rows x 4 columns]

# %%
relative_frequencies = glass_ceiling.apply(lambda x: x.value_counts(normalize=True))

relative_frequencies[q5].iloc[0] = relative_frequencies[q5].iloc[0]/3
relative_frequencies[q5].iloc[4] = relative_frequencies[q5].iloc[4]/3

relative_frequencies[q8].iloc[0] = relative_frequencies[q8].iloc[0]/3
relative_frequencies[q8].iloc[4] = relative_frequencies[q8].iloc[4]/3

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/4
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])


plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_83662/3551027262.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
height
# Out:
# 1.0    0.086279
# 2.0    0.065227
# 3.0    0.150707
# 4.0    0.170960
# 5.0    0.193493
# dtype: float64

# %%
glass_ceiling.describe()
# Out:
#        1. Έχετε αισθανθεί ποτέ ότι υπάρχει ένα εμπόδιο που σας εμποδίζει να προχωρήσετε στις υψηλόβαθμες θέσεις στον εργασιακό σας χώρο με βάση παράγοντες όπως το φύλο; (π.χ. μητρότητα/πατρότητα, μυϊκή δύναμη κτλ.)  \
# count                                         100.000000
# mean                                            3.720000
# std                                             1.875305
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        2. Πιστεύετε ότι ο χώρος εργασίας σας έχει μια ηγετική ομάδα που αντιπροσωπεύει διαφορετικά φύλα και υπόβαθρα;  \
# count                                         100.000000
# mean                                            3.310000
# std                                             1.107322
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        3. Πιστεύετε ότι ο χώρος εργασίας σας έχει δίκαιες και διαφανείς διαδικασίες πρόσληψης και προαγωγής που είναι απαλλαγμένες από διακρίσεις που αφορούν στο φύλο;  \
# count                                          99.000000
# mean                                            3.575758
# std                                             1.060332
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        4. Πιστεύετε ότι υπάρχει το φαινόμενο της γυάλινης οροφής (Glass Ceiling) στον κλάδο ή τον χώρο εργασίας σας;
# count                                          99.000000
# mean                                            3.464646
# std                                             1.955177
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000

# %%
parameter = glass_ceiling

individualScore = parameter.sum(axis=1)/4

# %%
gender = pd.concat([data['1. Φύλο:'],individualScore],axis=1)
gender.columns = ['Gender','Score']

# %%
from statistics import mean, pvariance

male = []
female = []

#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 'Γυναίκα':
        female.append(row['Score'])
    else:
        male.append(row['Score'])
        

avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 3.69375 var male = 0.7015234375 avg female = 3.370833333333333 var female = 0.9531076388888888

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.08388066147376838 T-Statistic:-1.7476121102041777

# %%
from statistics import mean, pvariance

no = []
yes = []

#create table for every category
for index, row in provider.iterrows(): 
    if row['Provider'] == 'Ναι':
        yes.append(row['Score'])
    else:
        no.append(row['Score'])
        
avg1 = mean(yes)
var1 = pvariance(yes)
avg2 = mean(no)
var2 = pvariance(no)

print("avg provider =", avg1,"var provider =",var1,"avg no =", avg2,"var no =",var2 )
# Out:
# avg provider = 3.8055555555555554 var provider = 0.9205246913580247 avg no = 3.8828125 var no = 0.64056396484375

# %%
tStat, pValue = stats.ttest_ind(yes, no, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.6871928287319998 T-Statistic:-0.4045565597037937

# %% [markdown]
# ### Parameter 3 Gender Descrimination

# %%
relative_frequencies = gender_descrimination.apply(lambda x: x.value_counts(normalize=True))

relative_frequencies[q9].iloc[0] = relative_frequencies[q9].iloc[0]/3
relative_frequencies[q9].iloc[4] = relative_frequencies[q9].iloc[4]/3

relative_frequencies[q12].iloc[0] = relative_frequencies[q12].iloc[0]/3
relative_frequencies[q12].iloc[4] = relative_frequencies[q12].iloc[4]/3

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/4
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])


plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_83662/4204398965.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
height
# Out:
# 1.0    0.142121
# 2.0    0.130000
# 3.0    0.120000
# 4.0    0.115000
# 5.0    0.159545
# dtype: float64

# %%
gender_descrimination.describe()
# Out:
#        1. Έχετε βιώσει ποτέ στερεοτυπικά σχόλια αναφορικά με το φύλο σας στον χώρο εργασίας;  \
# count                                          99.000000
# mean                                            2.818182
# std                                             2.001854
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        2. Έχετε αισθανθεί ποτέ ότι στερεότυπα για το φύλο επηρεάζουν κάποιον άλλο στο χώρο εργασίας;  \
# count                                         100.000000
# mean                                            2.450000
# std                                             1.175293
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        3. Πιστεύετε ότι τα στερεότυπα των φύλων έχουν επηρεάσει τις ευκαιρίες επαγγελματικής σας εξέλιξης ή τις αναθέσεις εργασίας σας;  \
# count                                         100.000000
# mean                                            3.330000
# std                                             1.172539
# min                                             1.000000
# 25%                                             2.750000
# 50%                                             3.500000
# 75%                                             4.000000
# max                                             5.000000
#
#        4. Έχετε υποστεί ποτέ παρενόχληση ή διάκριση με βάση τα στερεότυπα του φύλου στο χώρο εργασίας;
# count                                          100.00000
# mean                                             4.08000
# std                                              1.69181
# min                                              1.00000
# 25%                                              5.00000
# 50%                                              5.00000
# 75%                                              5.00000
# max                                              5.00000

# %%
parameter = gender_descrimination

individualScore = parameter.sum(axis=1)/4

# %%
gender = pd.concat([data['1. Φύλο:'],individualScore],axis=1)
gender.columns = ['Gender','Score']

# %%
from statistics import mean, pvariance

male = []
female = []

#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 'Γυναίκα':
        female.append(row['Score'])
    else:
        male.append(row['Score'])
        

avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 3.46875 var male = 0.9130859375 avg female = 2.9583333333333335 var female = 1.0940972222222223

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.014570024415319993 T-Statistic:-2.4918696522443753

# %%
from statistics import mean, pvariance

no = []
yes = []

#create table for every category
for index, row in provider.iterrows(): 
    if row['Provider'] == 'Ναι':
        yes.append(row['Score'])
    else:
        no.append(row['Score'])
        
avg1 = mean(yes)
var1 = pvariance(yes)
avg2 = mean(no)
var2 = pvariance(no)

print("avg provider =", avg1,"var provider =",var1,"avg no =", avg2,"var no =",var2 )
# Out:
# avg provider = 3.8055555555555554 var provider = 0.9205246913580247 avg no = 3.8828125 var no = 0.64056396484375

# %%
tStat, pValue = stats.ttest_ind(yes, no, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.6871928287319998 T-Statistic:-0.4045565597037937

# %% [markdown]
# ### Parameter 4 Descrimination in Recruitment

# %%
relative_frequencies = descrimination_recruitment.apply(lambda x: x.value_counts(normalize=True))

relative_frequencies[q13].iloc[0] = relative_frequencies[q13].iloc[0]/3
relative_frequencies[q13].iloc[4] = relative_frequencies[q13].iloc[4]/3

relative_frequencies[q16].iloc[0] = relative_frequencies[q16].iloc[0]/3
relative_frequencies[q16].iloc[4] = relative_frequencies[q16].iloc[4]/3

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/4
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])


plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_83662/4204398965.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
height
# Out:
# 1.0    0.184099
# 2.0    0.171717
# 3.0    0.078283
# 4.0    0.085859
# 5.0    0.146709
# dtype: float64

# %%
descrimination_recruitment.describe()
# Out:
#        1. Έχετε αισθανθεί ποτέ αδικία ή διάκριση  κατά τη διαδικασία πρόσληψης βάση παραγόντων όπως το φύλο;  \
# count                                         100.000000
# mean                                            3.840000
# std                                             1.824192
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        2. Έχει υποπέσει ποτέ στην αντίληψη σας ότι κάποιος υφίσταται αδικία ή διάκριση κατά τη διάρκεια της διαδικασίας πρόσληψης λόγω φύλου;  \
# count                                          99.000000
# mean                                            2.858586
# std                                             1.212268
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        3. Πιστεύετε ότι υπάρχουν προκαταλήψεις στη διαδικασία πρόσληψης που πλήττουν ορισμένες ομάδες ανθρώπων;  \
# count                                          99.000000
# mean                                            1.969697
# std                                             1.063826
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        4. Σας έχουν κάνει ποτέ ακατάλληλες ή αδιάκριτες ερωτήσεις κατά τη διάρκεια μιας συνέντευξης για δουλειά;
# count                                          99.000000
# mean                                            3.747475
# std                                             1.864510
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000

# %%
parameter = descrimination_recruitment

individualScore = parameter.sum(axis=1)/4

# %%
gender = pd.concat([data['1. Φύλο:'],individualScore],axis=1)
gender.columns = ['Gender','Score']

# %%
from statistics import mean, pvariance

male = []
female = []

#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 'Γυναίκα':
        female.append(row['Score'])
    else:
        male.append(row['Score'])
        

avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 3.275 var male = 0.59 avg female = 2.9541666666666666 var female = 1.2760243055555556

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.09742721954779968 T-Statistic:-1.6734661160496167

# %%
from statistics import mean, pvariance

no = []
yes = []

#create table for every category
for index, row in provider.iterrows(): 
    if row['Provider'] == 'Ναι':
        yes.append(row['Score'])
    else:
        no.append(row['Score'])
        
avg1 = mean(yes)
var1 = pvariance(yes)
avg2 = mean(no)
var2 = pvariance(no)

print("avg provider =", avg1,"var provider =",var1,"avg no =", avg2,"var no =",var2 )
# Out:
# avg provider = 3.8055555555555554 var provider = 0.9205246913580247 avg no = 3.8828125 var no = 0.64056396484375

# %%
tStat, pValue = stats.ttest_ind(yes, no, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.6871928287319998 T-Statistic:-0.4045565597037937
